# %%
import pandas as pd
import numpy as np 
data=pd.read_csv(r'C:\Users\kamau\Downloads\titanic3.csv')

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.replace({'male':1,'female':0},inplace=True)
# Out:
# C:\Users\kamau\AppData\Local\Temp\ipykernel_8156\1479493549.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'male':1,'female':0},inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   int64
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 143.3+ KB

# %%
data.corr(numeric_only=True).abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data =data[['sex', 'pclass','age','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(x_test)
print(metrics.accuracy_score(y_test,predict_test))
# Out:
# 0.7799043062200957

# %%
#Neural Networks 

from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(4, kernel_initializer = 'uniform', activation = 'relu', input_dim = 4))
model.add(Dense(4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 20
#
#  dense_1 (Dense)             (None, 4)                 20
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 45
# Trainable params: 45
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 2s 6ms/step - loss: 0.6924 - accuracy: 0.5837
# Epoch 2/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6902 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6873 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6818 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6725 - accuracy: 0.6447
# Epoch 6/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6581 - accuracy: 0.7620
# Epoch 7/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6366 - accuracy: 0.7799
# Epoch 8/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6100 - accuracy: 0.7727
# Epoch 9/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5817 - accuracy: 0.7751
# Epoch 10/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5568 - accuracy: 0.7763
# Epoch 11/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5350 - accuracy: 0.7739
# Epoch 12/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.5168 - accuracy: 0.7751
# Epoch 13/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7751
# Epoch 14/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4945 - accuracy: 0.7739
# Epoch 15/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4871 - accuracy: 0.7763
# Epoch 16/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4815 - accuracy: 0.7823
# Epoch 17/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4774 - accuracy: 0.7787
# Epoch 18/50
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4744 - accuracy: 0.7811
# Epoch 19/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4722 - accuracy: 0.7835
# Epoch 20/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4705 - accuracy: 0.7811
# Epoch 21/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4693 - accuracy: 0.7823
# Epoch 22/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4682 - accuracy: 0.7811
# Epoch 23/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4671 - accuracy: 0.7787
# Epoch 24/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4663 - accuracy: 0.7799
# Epoch 25/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4650 - accuracy: 0.7811
# Epoch 26/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4640 - accuracy: 0.7823
# Epoch 27/50
# 27/27 [==============================] - 0s 15ms/step - loss: 0.4628 - accuracy: 0.7847
# Epoch 28/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4617 - accuracy: 0.7847
# Epoch 29/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4612 - accuracy: 0.7847
# Epoch 30/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4601 - accuracy: 0.7859
# Epoch 31/50
# 27/27 [==============================] - 2s 61ms/step - loss: 0.4596 - accuracy: 0.7835
# Epoch 32/50
# 27/27 [==============================] - 1s 36ms/step - loss: 0.4586 - accuracy: 0.7871
# Epoch 33/50
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4574 - accuracy: 0.7895
# Epoch 34/50
# 27/27 [==============================] - 1s 47ms/step - loss: 0.4567 - accuracy: 0.7895
# Epoch 35/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4560 - accuracy: 0.7883
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4555 - accuracy: 0.7883
# Epoch 37/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4561 - accuracy: 0.7883
# Epoch 38/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4547 - accuracy: 0.7883
# Epoch 39/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4541 - accuracy: 0.7871
# Epoch 40/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.7859
# Epoch 41/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7835
# Epoch 42/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.7847
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4528 - accuracy: 0.7835
# Epoch 44/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.7835
# Epoch 45/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4522 - accuracy: 0.7835
# Epoch 46/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4521 - accuracy: 0.7835
# Epoch 47/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4517 - accuracy: 0.7835
# Epoch 48/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4515 - accuracy: 0.7847
# Epoch 49/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.4513 - accuracy: 0.7847
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7847
